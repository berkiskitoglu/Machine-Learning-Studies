# %%
name = "Halit"

# %%
type(name)
# Out:
# str

# %%
name:str = "Halit"

# %%
surname : str =  20

# %%
type(surname)
# Out:
# int

# %%
def add_numbers(a:int,b:int) -> int:
    return a + b

# %%
add_numbers(3,5)
# Out:
# 8

# %%
def process_value(value: int | str) -> str:
    if isinstance(value,int):
        return f"proceseed integer {value}"
    else:
        return f"processed string {value}"

# %%
process_value(60)
# Out:
# 'proceseed integer 60'

# %%
process_value("test")
# Out:
# 'processed string test'

# %%
from typing import List

def sum_list(numbers: List[int]) -> int:
    return sum(numbers)

# %%
numbers = [1,2,3,4]
total = sum_list(numbers)
total
# Out:
# 10

# %%
def divide_number(number):
    return number / 2

# %%
divide_number(12)
# Out:
# 6.0

# %%
my_list = [3,5,7,10,20,30]

# %%
my_result_list = []
for number in my_list:
    my_result_list.append(divide_number(number))

# %%
my_result_list
# Out:
# [1.5, 2.5, 3.5, 5.0, 10.0, 15.0]

# %% [markdown]
# # map

# %%
help(map)
# Out:
# Help on class map in module builtins:
#
# class map(object)
#  |  map(function, iterable, /, *iterables)
#  |
#  |  Make an iterator that computes the function using arguments from
#  |  each of the iterables.  Stops when the shortest iterable is exhausted.
#  |
#  |  Methods defined here:
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __next__(self, /)
#  |      Implement next(self).
#  |
#  |  __reduce__(self, /)
#  |      Return state information for pickling.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs)
#  |      Create and return a new object.  See help(type) for accurate signature.

# %%
list(map(divide_number,my_list))
# Out:
# [1.5, 2.5, 3.5, 5.0, 10.0, 15.0]

# %%
def control_string(string):
    return "Halit" in string

# %%
control_string("Halit iskitoğlu")
# Out:
# True

# %%
my_string_list = ["Halit","Halit İskitoğlu","Berk","İskitoğlu"]

# %%
list(map(control_string,my_string_list))
# Out:
# [True, True, False, False]

# %% [markdown]
# # filter

# %%
list(filter(control_string,my_string_list))
# Out:
# ['Halit', 'Halit İskitoğlu']

# %% [markdown]
# # lambda

# %%
multiply_lambda = lambda num : num * 3

# %%
type(multiply_lambda)
# Out:
# function

# %%
multiply_lambda(20)
# Out:
# 60

# %%
result = multiply_lambda(10)

# %%
result
# Out:
# 30

# %%
number_list = [10,20,30,40,50]

# %%
list(map(lambda num : num / 4,number_list))
# Out:
# [2.5, 5.0, 7.5, 10.0, 12.5]

# %% [markdown]
# # scope

# %%
x = 20

def multiply(number):
    x = 5
    return number * x

# %%
multiply(10)
# Out:
# 50

# %%
print(x)
# Out:
# 20

# %%
a = 10

# %%
a
# Out:
# 10

# %%
a = 20

# %%
a
# Out:
# 20

# %%
x = 20

def multiply(number):
    x = 5
    return number * x
x = 10

# %%
x
# Out:
# 10

# %%
multiply(3)
# Out:
# 15

# %%
x = 20

def multiply(number):
    return number * x

# %%
multiply(10)
# Out:
# 200

# %% [markdown]
# # LEGB -> L -> Local , E -> Encolosing , G -> Global , B -> Built-In

# %%
#Global
my_string = "halit"
def my_function():
    #Encolsing
    my_string = "halit 2"
    print(my_string)
    def my_function2():
        #Local
        my_string = "halit 3"
        print(my_string)
    my_function2()

# %%
my_string
# Out:
# 'halit'

# %%
my_function()
# Out:
# halit 2
# halit 3

# %%
def test1():
    my_variable = 10
    print(my_variable * 2)

def test2():
    print(my_variable * 3)

# %%
test1()
# Out:
# 20

# %%
#test2()

# %%
y = 10
def new_function(y):
    print(y)
    y = 5
    print(y)
    return y

# %%
new_function(10)
# Out:
# 10
# 5
# 5

# %%
y
# Out:
# 10

# %%
y = 10
def change_y():
    global y
    y = 5
    print(y)

# %%
y
# Out:
# 10

# %%
change_y()
# Out:
# 5

# %%
y
# Out:
# 5

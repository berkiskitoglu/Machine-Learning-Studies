# %%
age = input("enter age: ")
# Out:
# enter age:  32

# %%
age
# Out:
# '32'

# %%
int(age) * 2
# Out:
# 64

# %%
# try - except

# %%
while True:
    try:
        myAge = int(input("enter age: "))
        print(myAge * 2)
    except ValueError:
        print("enter your age !!")
    else:
        print("else executed")
        break
    finally:
        print("finally")
# Out:
# enter age:  aşli
# enter your age !!
# finally
# enter age:  21
# 42
# else executed
# finally

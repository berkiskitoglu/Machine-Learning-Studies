# %%
x = 5
y = 2

# %%
x > y
# Out:
# True

# %%
x < y
# Out:
# False

# %%
y = 5

# %%
x >= y
# Out:
# True

# %%
x
# Out:
# 5

# %%
y
# Out:
# 5

# %%
x >= 5.0
# Out:
# True

# %%
x >= 5.0001
# Out:
# False

# %%
x = 10
y = 8
x,y
# Out:
# (10, 8)

# %%
x = y

# %%
x
# Out:
# 8

# %%
x = 10

# %%
x == y
# Out:
# False

# %%
x != y
# Out:
# True

# %%
2 > 1 and 3 > 2
# Out:
# True

# %%
2 > 1 and 3 < 2
# Out:
# False

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and False
# Out:
# False

# %%
2 > 1 or 3 < 2
# Out:
# True

# %%
1 > 2 or 3 < 2
# Out:
# False

# %%
not 1 == 1
# Out:
# False

# %%
10 in [10,20,30]
# Out:
# True

# %%
5 not in [10,20,30]
# Out:
# True

# %%
10 in {10,20,30}
# Out:
# True

# %%
my_dictionary = {"a":10,"b":20,"c":30}

# %%
10 in my_dictionary.values()
# Out:
# True

# %%
"b" in my_dictionary.keys()
# Out:
# True

# %%
10 in (10,20,30)
# Out:
# True

# %%
my_superhero = "Aquaman"

# %%
my_superhero == "Batman"
# Out:
# False

# %%
my_superhero == "Superman"
# Out:
# False

# %%
if my_superhero == "Batman":
    # indentation - boşluk
    print("batmannn")
    print("halit iskitoğlu")  
########----------##########
print("hello python")
# Out:
# hello python

# %%
if 3 > 2:
    print("hello world")
    print("halit")
# Out:
# hello world
# halit

# %%
my_superhero = input("enter superhero:")

# %%
if my_superhero == "Superman":
    print("Superman")
elif my_superhero == "Batman":
    print("Batman")
elif my_superhero == "Aquaman":
    print("Aquaman")
elif my_superhero == "Ironman":
    print("IronMan")
else:
    print(":(")

# %%
my_age = 18

# %%
if my_age <= 18:
    print("age <= 18")
elif my_age >= 18 and my_age <= 30:
    print("18 - age - 30")
elif my_age > 30 and my_age <= 40:
    print("30 - age - 40")
else:
    print("age > 40")

# %%
my_superhero = input("enter superhero:")

# %%
my_superhero_list = ["Spiderman","Iron Man","Thor","Black Widow"]

# %%
if my_superhero in my_superhero_list:
    print(":)")
else:
    print(":(")

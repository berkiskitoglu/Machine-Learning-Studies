# %%
hali_name = "Halit"

# %%
halit_age = 24

# %%
halit_gender = "Male"

# %%
atlas_name = "Atlas"

# %%
atlas_age = 20

# %%
atlas_gender = "Male"

# %%
class Person():
    # Property
    # name = ""
    # age = 0
    # gender = ""
    job = "developer"
    # initializer method
    def __init__(self,name,age,gender):
        self.name = name
        self.age = age
        self.gender = gender
    # method
    def print_name(self):
       print(self.name)

# %%
my_list = list()

# %%
halit = Person("Halit",25,"Male")

# %%
halit.age
# Out:
# 25

# %%
halit.name
# Out:
# 'Halit'

# %%
halit.print_name()
# Out:
# Halit

# %%
halit.job = "Developer"

# %%
halit.job
# Out:
# 'Developer'

# %%
class Dog():
    year = 7
    def __init__(self,age=5):
        self.age = age
        self.dog_human_age = age * self.year
    def human_age(self):
        return self.age * Dog.year # Dog.year -> self.year

# %%
my_dog = Dog(3)

# %%
my_dog.age
# Out:
# 3

# %%
my_dog.human_age()
# Out:
# 21

# %%
my_dog.dog_human_age
# Out:
# 21

# %%
barly = Dog()

# %%
barly.dog_human_age
# Out:
# 35
